# %%
import pyodbc

server = 'TECH-99'
database = 'chem_prod_copy'
username = 'sa'
password = '123456'

connection_string = f"DRIVER={{SQL Server}};SERVER={server};DATABASE={database};UID={username};PWD={password}"

conn = pyodbc.connect(connection_string)
cursor = conn.cursor()
print(cursor)

# %%
cursor.execute("SELECT TABLE_NAME FROM INFORMATION_SCHEMA.TABLES WHERE TABLE_TYPE = 'BASE TABLE'")

tables = [row.TABLE_NAME for row in cursor.fetchall()]
print(tables)
# Out:
# ['SA_ChemPriceWeeklyNew', 'SA_CommentaryPricing', 'SA_Commentary']

# %%
query = "SELECT * FROM SA_Commentary"
df = pd.read_sql(query, conn)

#print(df)

# Close the connection
conn.close()
# Out:
# C:\Users\web.dev-1\AppData\Local\Temp\ipykernel_14468\1332852291.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)

# %%
#df.head()

# %%
cursor.execute("SELECT TABLE_NAME FROM INFORMATION_SCHEMA.TABLES WHERE TABLE_TYPE = 'BASE TABLE'")

tables = [row.TABLE_NAME for row in cursor.fetchall()]
print(tables)

# Close the connection
#cursor.close()
#conn.close()
# Out:
# ['SA_ChemPriceWeeklyNew', 'SA_CommentaryPricing', 'SA_Commentary']

# %%
week.columns
# Out:
# Index(['id', 'Product', 'ProductVariant', 'Type', 'year', 'Week', 'Date',
#        'count', 'FileName', 'CreatedDate', 'CreatedBy', 'Country', 'Region',
#        'USD', 'Min', 'Max', 'MinUSD', 'MaxUSD', 'UpdatedDate', 'Source',
#        'ApprovalDate', 'ApprovedBy', 'Flag', 'SourceDesc', 'CommentaryFlag',
#        'ExtCommentaryFlag'],
#       dtype='object')

# %%
week.head()
# Out:
#         id  Product                          ProductVariant  \
# 0  8760369    11111                                    None
# 1  8760370     2222                                    None
# 2  8760371     3333                                    None
# 3  8645914      138             Anhydrous Ammonia CFR Tampa
# 4  8640869      113  Ethylene Vinyl Acetate 28% FOB Tianjin
#
#                            Type  year     Week             Date   count  \
# 0                          None  None     None             None     NaN
# 1                          None  None     None             None     NaN
# 2                          None  None     None             None     NaN
# 3                       Ammonia  2023  W2-2023  13-January-2023  1060.0
# 4  Ethylene Vinyl Acetate (EVA)  2023  W1-2023  06-January-2023  2765.0
#
#                                          FileName             CreatedDate  \
# 0                                            None                     NaT
# ...

# %%
week['year'] = pd.DatetimeIndex(week['Date']).year
week['month'] = pd.DatetimeIndex(week['Date']).month

# %%
clean_test=week[['Product','month','year']].drop_duplicates()
clean_test2=clean_test.drop_duplicates()
dd22=clean_test2.loc[clean_test2['year']==2023]
jan=dd22.loc[dd22['month']==7]
print(len(jan.Product.unique()))
# Out:
# 240

# %%
print(240*500*0.002)
# Out:
# 240.0

# %%
market['Demand'].isnull().sum()
# Out:
# 288

# %%
#est_summ=market.loc[market['Januaryarch"]
clean_test=market[['Product','Month','year','MarketSituation','Demand','Supply','PlantShutdown']].drop_duplicates()
clean_test2=clean_test.drop_duplicates()
clean_test2.head()
# Out:
#    Product  Month  year MarketSituation           Demand    Supply  \
# 0      579   None  2023         Bearish  Low to Moderate  Moderate
# 1      579  March  2023         Bearish  Low to Moderate  Moderate
# 2      327   None  2023         Bearish         Moderate  Moderate
# 3      327  March  2023         Bearish         Moderate  Moderate
# 4      579   None  2023         Bearish  Low to Moderate  Moderate
#
#   PlantShutdown
# 0             n
# 1             n
# 2       no info
# 3       no info
# 4             m

# %%
dt22=clean_test.loc[clean_test['year']=='2023']
march=dt22.loc[dt22['Month']=='September']
print(len(march.Product.unique()))
# Out:
# 453

# %%
march
# Out:
#        Product     Month  year MarketSituation    Demand    Supply  \
# 41016      368  December  2023         Bearish  Moderate  Moderate
#
#       PlantShutdown
# 41016            na

# %%
dt22['Month'].value_counts()
# Out:
# September    834
# June         814
# August       792
# July         741
# October      720
# November     680
# March        543
# April        481
# May          479
# January        2
# February       2
# December       1
# Name: Month, dtype: int64

# %%
120500*0.002
# Out:
# 241.0

# %%
## add table which captures insert operations 
new_table="""
CREATE TABLE tracking (
    LogID INT PRIMARY KEY IDENTITY(1,1),
    Product INT,
    ProductVariant_week NVARCHAR(255),
    type_week NVARCHAR(255),
    year Date,
    Week Date,
    Date Date,
    count INT,
    Min INT,
    Max INT,
    Country_week NVARCHAR(255),
    Region_week NVARCHAR(255),
    
    
    
    
    Country_market INT,
    Range INT,
    RegionID INT,
    WeekDate Date,
    ProductVarient_market NVARCHAR(255),
    type_market NVARCHAR(255),
    MarketSituation NVARCHAR(255),
    Demand NVARCHAR(255),
    Supply NVARCHAR(255),
    PlantShutdown NVARCHAR(255),
    IsActive INT,
    InsertedDateTime DATETIME DEFAULT GETDATE()
);


"""
cursor.execute(new_table)
conn.commit()

# %%
### adding triggers for CDC :
sql_trigger = """
CREATE TRIGGER trg_AfterInsertProducts_week
ON SA_ChemPriceWeeklyNew
AFTER INSERT
AS
BEGIN
    INSERT INTO tracking (Product, ProductVariant_week,type_week,year,Week,Date,count,Min,Max,Country_week,Region_week)
    SELECT Product, ProductVariant, Type, year,Week,Date,count,Min,Max,Country,Region  FROM inserted
END
"""

# Execute the SQL statement
cursor.execute(sql_trigger)
conn.commit()
sql_trigger2='''

CREATE TRIGGER trg_AfterInsertProducts_market
ON SA_CommentaryPricing
AFTER INSERT
AS
BEGIN
    INSERT INTO tracking (Country_market, Range,RegionID,WeekDate,ProductVarient_market,type_market,MarketSituation,Demand,Supply,PlantShutDown,IsActive)
    SELECT Country, Range,RegionID,WeekDate,ProductVarient,Type,MarketSituation,Demand,Supply,PlantShutDown,IsActive FROM inserted
END;

'''

cursor.execute(sql_trigger2)
conn.commit()
#last_processed_log_id = 0

#while True:
#    query = f"SELECT * FROM ProductLog WHERE LogID > {last_processed_log_id} ORDER BY LogID"
#    cursor.execute(query)
    
#    logs = cursor.fetchall()
#    for log in logs:
        # Process the log data here (print, store, or any other operation)
#        print(log)
#        last_processed_log_id = log.LogID

    # Sleep for a defined interval (e.g., 10 seconds) before checking again
#    time.sleep(10)

# Close the connection (though in this example it won't be reached because of the infinite loop)
#cursor.close()
#conn.close()

# %%
import pandas as pd
import time

# Function to call the API (dummy function for illustration)
def call_api_and_generate_summary(product, product_variant):
    # Your API call and summary generation logic here
    return "Generated Summary"

last_processed_log_id = 0

def fetch_processed_logs():
    
    # Fetch logs with 'Status' marked as 'Done' from the database
    # and return them as a list of dictionaries
    # Example:
    # return [{'LogID': 1, 'Product': 'ProductA', 'ProductVariant': 'VariantA', 'InsertedDateTime': '2023-09-22', 'Status': 'Done'}]
    pass

previously_processed_logs = fetch_processed_logs()

# Initialize df_logs with previously processed logs
if previously_processed_logs:
    df_logs = pd.DataFrame(previously_processed_logs)
else:
    df_logs = pd.DataFrame(columns=['LogID', 'Product', 'ProductVariant', 'InsertedDateTime', 'Status'])

while True:
    new_logs_list = []

    query = f"SELECT * FROM ProductLog WHERE LogID > {last_processed_log_id} ORDER BY LogID"
    cursor.execute(query)
    logs = cursor.fetchall()

    for log in logs:
        # Check if this LogID is already processed and marked as 'Done'
        if not df_logs[(df_logs['LogID'] == log[0]) & (df_logs['Status'] == 'Done')].empty:
            print(f"Skipping LogID {log[0]} as it is already done.")
            continue

        # Process the log data here (print, store, or any other operation)
        print(log)
        last_processed_log_id = log[0]  # Assuming LogID is the first column

        # Call API and generate summary
        summary = call_api_and_generate_summary(log[1], log[2])

        log_dict = {
            'LogID': log[0],
            'Product': log[1],
            'ProductVariant': log[2],
            'InsertedDateTime': log[3],
            'Status': 'Done' if summary else 'Pending'
        }
        new_logs_list.append(log_dict)

    # Append new logs to the DataFrame only if there are new logs
    if new_logs_list:
        df_new_logs = pd.DataFrame(new_logs_list)
        df_logs = pd.concat([df_logs, df_new_logs], ignore_index=True)

    # Sleep for a defined interval (e.g., 10 seconds) before checking again
    time.sleep(10)
# Out:
# (1, 11111, None, datetime.datetime(2023, 9, 19, 15, 48, 33, 647000))
# (2, 2222, None, datetime.datetime(2023, 9, 19, 16, 1, 46, 940000))
# (3, 3333, None, datetime.datetime(2023, 9, 20, 11, 28, 59, 597000))
# (4, 4444, None, datetime.datetime(2023, 9, 21, 15, 7, 37, 447000))
# (5, 44445, None, datetime.datetime(2023, 9, 21, 15, 24, 36, 920000))
# (6, 55555, None, datetime.datetime(2023, 9, 22, 9, 27, 45, 367000))
# (7, 66666, None, datetime.datetime(2023, 9, 22, 9, 47, 36, 830000))
# (8, 7777, None, datetime.datetime(2023, 9, 22, 11, 7, 20, 330000))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[125], line 61
#      58     df_logs = pd.concat([df_logs, df_new_logs], ignore_index=True)
#      60 # Sleep for a defined interval (e.g., 10 seconds) before checking again
# ---> 61 time.sleep(10)
#
# KeyboardInterrupt:

# %%
# Function to call the API (dummy function for illustration)
def call_api_and_generate_summary(product, product_variant):
    # Your API call and summary generation logic here
    
    return "Generated Summary"

last_processed_log_id = 0
df_logs = pd.DataFrame(columns=['LogID', 'Product', 'ProductVariant', 'InsertedDateTime', 'Status'])

while True:
    new_logs_list = []
    

    query = f"SELECT * FROM ProductLog WHERE LogID > {last_processed_log_id} ORDER BY LogID"
    cursor.execute(query)

    logs = cursor.fetchall()

    for log in logs:
        # Check if this LogID is already processed and marked as 'Done'
        if not df_logs[(df_logs['LogID'] == log[0]) & (df_logs['Status'] == 'Done')].empty:
            print(f"Skipping LogID {log[0]} as it is already done.")
            continue

        # Process the log data here (print, store, or any other operation)
        print(log)
        last_processed_log_id = log[0]  # Assuming LogID is the first column

        # Call API and generate summary
        summary = call_api_and_generate_summary(log[1], log[2])

        log_dict = {
            'LogID': log[0],
            'Product': log[1],
            'ProductVariant': log[2],
            'InsertedDateTime': log[3],
            'Status': 'Done' if summary else 'Pending'
        }
        new_logs_list.append(log_dict)
            
    # Append new logs to the DataFrame only if there are new logs
    if new_logs_list:
        df_new_logs = pd.DataFrame(new_logs_list)
        df_logs = pd.concat([df_logs, df_new_logs], ignore_index=True)
        
    # Sleep for a defined interval (e.g., 10 seconds) before checking again
    time.sleep(10)
# Out:
# (1, 11111, None, datetime.datetime(2023, 9, 19, 15, 48, 33, 647000))
# (2, 2222, None, datetime.datetime(2023, 9, 19, 16, 1, 46, 940000))
# (3, 3333, None, datetime.datetime(2023, 9, 20, 11, 28, 59, 597000))
# (4, 4444, None, datetime.datetime(2023, 9, 21, 15, 7, 37, 447000))
# (5, 44445, None, datetime.datetime(2023, 9, 21, 15, 24, 36, 920000))
# (6, 55555, None, datetime.datetime(2023, 9, 22, 9, 27, 45, 367000))
# (7, 66666, None, datetime.datetime(2023, 9, 22, 9, 47, 36, 830000))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[77], line 46
#      43     df_logs = pd.concat([df_logs, df_new_logs], ignore_index=True)
#      45 # Sleep for a defined interval (e.g., 10 seconds) before checking again
# ---> 46 time.sleep(10)
#
# KeyboardInterrupt:

# %%
df_logs
# Out:
#   LogID Product ProductVariant        InsertedDateTime Status
# 0     1   11111           None 2023-09-19 15:48:33.647   Done
# 1     2    2222           None 2023-09-19 16:01:46.940   Done
# 2     3    3333           None 2023-09-20 11:28:59.597   Done
# 3     4    4444           None 2023-09-21 15:07:37.447   Done
# 4     5   44445           None 2023-09-21 15:24:36.920   Done
# 5     6   55555           None 2023-09-22 09:27:45.367   Done
# 6     7   66666           None 2023-09-22 09:47:36.830   Done

# %%
week.head()
# Out:
#         id  Product                          ProductVariant  \
# 0  8760369    11111                                    None
# 1  8760370     2222                                    None
# 2  8760371     3333                                    None
# 3  8645914      138             Anhydrous Ammonia CFR Tampa
# 4  8640869      113  Ethylene Vinyl Acetate 28% FOB Tianjin
#
#                            Type  year     Week             Date   count  \
# 0                          None  None     None             None     NaN
# 1                          None  None     None             None     NaN
# 2                          None  None     None             None     NaN
# 3                       Ammonia  2023  W2-2023  13-January-2023  1060.0
# 4  Ethylene Vinyl Acetate (EVA)  2023  W1-2023  06-January-2023  2765.0
#
#                                          FileName             CreatedDate  \
# 0                                            None                     NaT
# ...

# %%
### Analyzing data from here 
## ['SA_ChemPriceWeeklyNew', 'SA_CommentaryPricing', 'SA_Commentary']

# %%
import pandas as pd
query = "SELECT * FROM SA_Commentary"
com = pd.read_sql(query, conn)
query1 = 'SELECT * FROM SA_ChemPriceWeeklyNew'
week=pd.read_sql(query1,conn)
query2 = ' SELECT * FROM SA_CommentaryPricing'
market=pd.read_sql(query2,conn)
# Close the connection                                        
conn.close()
# Out:
# C:\Users\web.dev-1\AppData\Local\Temp\ipykernel_13636\723378360.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   com = pd.read_sql(query, conn)
# C:\Users\web.dev-1\AppData\Local\Temp\ipykernel_13636\723378360.py:5: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   week=pd.read_sql(query1,conn)
# C:\Users\web.dev-1\AppData\Local\Temp\ipykernel_13636\723378360.py:7: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   market=pd.read_sql(query2,conn)

# %%
com.head()
# Out:
#     id                                              Title              Type  \
# 0  714    Insights on Polyolefin Elastomer Price Movement  Chemical Pricing
# 1  715  Insights on Thermo Plastic Elastomer (TPE) Pri...  Chemical Pricing
# 2  719  Insights on Thermo Plastic Elastomer (TPE) Pri...  Chemical Pricing
# 3  721              Insights on Helium Gas Price Movement  Chemical Pricing
# 4  724              Insights on Helium Gas Price Movement  Chemical Pricing
#
#                                          Description  Meta MetaDescription  \
# 0  <div>\r\n\t<div>\r\n\t\t&nbsp;</div>\r\n\t<div...  None            None
# 1  <div>\r\n\tDue to less demand, northeast Asian...  None            None
# 2  <div>\r\n\tPrices of the raw material went dow...  None            None
# 3  <div>\r\n\tThe cost of Helium Gas has risen by...  None            None
# 4  <div>\r\n\tTight supplies made the price incre...  None            None
#
# ...

# %%
week.head()
# Out:
#         id  Product                          ProductVariant  \
# 0  8760369    11111                                    None
# 1  8760370     2222                                    None
# 2  8760371     3333                                    None
# 3  8645914      138             Anhydrous Ammonia CFR Tampa
# 4  8640869      113  Ethylene Vinyl Acetate 28% FOB Tianjin
#
#                            Type  year     Week             Date   count  \
# 0                          None  None     None             None     NaN
# 1                          None  None     None             None     NaN
# 2                          None  None     None             None     NaN
# 3                       Ammonia  2023  W2-2023  13-January-2023  1060.0
# 4  Ethylene Vinyl Acetate (EVA)  2023  W1-2023  06-January-2023  2765.0
#
#                                          FileName             CreatedDate  \
# 0                                            None                     NaT
# ...

# %%
market.head()
# Out:
#      Id Country  Product  Range  RegionID   Day       WeekDate  Month  year  \
# 0  2325      70      579      4       3.0  None  31-March-2023   None  2023
# 1  2326      70      579      2       3.0  None           None  March  2023
# 2  2327       5      327      4       1.0  None  31-March-2023   None  2023
# 3  2328       5      327      2       1.0  None           None  March  2023
# 4  2329       4      579      4       4.0  None  31-March-2023   None  2023
#
#                            ProductVarient              Type MarketSituation  \
# 0  Hexamethylenetetramine FOB Novosibirsk  Chemical Pricing         Bearish
# 1  Hexamethylenetetramine FOB Novosibirsk  Chemical Pricing         Bearish
# 2                 Methyl Amine Ex-Qingdao  Chemical Pricing         Bearish
# 3                 Methyl Amine Ex-Qingdao  Chemical Pricing         Bearish
# 4    Hexamethylenetetramine FOB Al Jubail  Chemical Pricing         Bearish
#
# ...

# %%
test_pro=market.loc[market['Product']==53]
test_pro=test_pro[['Country','Product','WeekDate','Month','ProductVarient','Type','MarketSituation','Demand','Supply','PlantShutdown']]
test_week=week.loc[week['Product']==53]
test_week=test_week[['Product','ProductVariant','Type','Date','count','Min','Max']]
test_comm=com.loc[com['Product']==53]
test_comm=test_comm[['Title','Type','Description','Product']]

# %%
test_comm.head()
# Out:
#                                                   Title              Type  \
# 0       Insights on Polyolefin Elastomer Price Movement  Chemical Pricing
# 3261  Insights on Polyolefin Elastomer (POE) Price M...  Chemical Pricing
# 3905  Insights on USA Polyolefin Elastomers (POE) Pr...  Chemical Pricing
# 3906  Insights on US Polyolefin Elastomers (POE) Pri...  Chemical Pricing
# 3907  Insights on USA Polyolefin Elastomers (POE) Pr...  Chemical Pricing
#
#                                             Description  Product
# 0     <div>\r\n\t<div>\r\n\t\t&nbsp;</div>\r\n\t<div...       53
# 3261  <p>\r\n\tPrices of Butene based Polyolefin Ela...       53
# 3905  <div>\r\n\tUS suppliers reported constrained i...       53
# 3906  <div>\r\n\tAs per a market respondent, supply/...       53
# 3907  <div>\r\n\tContinued rally in crude oil prices...       53

# %%
#dfs = [test_week, test_comm, test_pro]
#testing=test_week.merge(test_comm,on='Product').merge(test_pro,on='Product')

# %%
test=pd.merge(test_week,test_pro,on=['Product'],how='inner')
test.head()
# Out:
#    Product                                ProductVariant  \
# 0       53  POE Butene-based Extrusion Grade FOB-Incheon
# 1       53  POE Butene-based Extrusion Grade FOB-Incheon
# 2       53  POE Butene-based Extrusion Grade FOB-Incheon
# 3       53  POE Butene-based Extrusion Grade FOB-Incheon
# 4       53  POE Butene-based Extrusion Grade FOB-Incheon
#
#                        Type_x          Date   count     Min     Max Country  \
# 0  Polyolefin Elastomer (POE)  14-July-2023  2710.0  2620.0  2800.0       5
# 1  Polyolefin Elastomer (POE)  14-July-2023  2710.0  2620.0  2800.0       5
# 2  Polyolefin Elastomer (POE)  14-July-2023  2710.0  2620.0  2800.0       9
# 3  Polyolefin Elastomer (POE)  14-July-2023  2710.0  2620.0  2800.0       9
# 4  Polyolefin Elastomer (POE)  14-July-2023  2710.0  2620.0  2800.0      18
#
#         WeekDate  Month                                ProductVarient  \
# 0  31-March-2023   None                 POE Butene Based CFR Shanghai
# ...

# %%
test_clean=test.drop_duplicates()
test_clean.head()
# Out:
#    Product                                ProductVariant  \
# 0       53  POE Butene-based Extrusion Grade FOB-Incheon
# 1       53  POE Butene-based Extrusion Grade FOB-Incheon
# 2       53  POE Butene-based Extrusion Grade FOB-Incheon
# 3       53  POE Butene-based Extrusion Grade FOB-Incheon
# 4       53  POE Butene-based Extrusion Grade FOB-Incheon
#
#                        Type_x          Date   count     Min     Max Country  \
# 0  Polyolefin Elastomer (POE)  14-July-2023  2710.0  2620.0  2800.0       5
# 1  Polyolefin Elastomer (POE)  14-July-2023  2710.0  2620.0  2800.0       5
# 2  Polyolefin Elastomer (POE)  14-July-2023  2710.0  2620.0  2800.0       9
# 3  Polyolefin Elastomer (POE)  14-July-2023  2710.0  2620.0  2800.0       9
# 4  Polyolefin Elastomer (POE)  14-July-2023  2710.0  2620.0  2800.0      18
#
#         WeekDate  Month                                ProductVarient  \
# 0  31-March-2023   None                 POE Butene Based CFR Shanghai
# ...

# %%
test_clean.loc[test_clean['Country']=='5']
# Out:
#         Product                                   ProductVariant  \
# 0            53     POE Butene-based Extrusion Grade FOB-Incheon
# 1            53     POE Butene-based Extrusion Grade FOB-Incheon
# 18           53     POE Butene-based Extrusion Grade FOB-Incheon
# 27           53     POE Butene-based Extrusion Grade FOB-Incheon
# 36           53     POE Butene-based Extrusion Grade FOB-Incheon
# ...         ...                                              ...
# 273842       53  POE Butene-based Injection Moulding FOB-Incheon
# 273851       53  POE Butene-based Injection Moulding FOB-Incheon
# 273860       53  POE Butene-based Injection Moulding FOB-Incheon
# 273869       53  POE Butene-based Injection Moulding FOB-Incheon
# 273879       53  POE Butene-based Injection Moulding FOB-Incheon
#
#                             Type_x               Date   count     Min     Max  \
# 0       Polyolefin Elastomer (POE)       14-July-2023  2710.0  2620.0  2800.0
# ...

# %%
#test_clean2=test_clean[:1000]
test_clean2.to_excel('C:\Users\web.dev-1\Downloads\testing_data.xlsx')
# Out:
#   Cell In[129], line 2
#     test_clean2.to_excel('C:\Users\web.dev-1\Downloads\testing_data.xlsx')
#                                                                          ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
test_clean2.head()
# Out:
#    Product                                ProductVariant  \
# 0       53  POE Butene-based Extrusion Grade FOB-Incheon
# 1       53  POE Butene-based Extrusion Grade FOB-Incheon
# 2       53  POE Butene-based Extrusion Grade FOB-Incheon
# 3       53  POE Butene-based Extrusion Grade FOB-Incheon
# 4       53  POE Butene-based Extrusion Grade FOB-Incheon
#
#                        Type_x          Date   count     Min     Max Country  \
# 0  Polyolefin Elastomer (POE)  14-July-2023  2710.0  2620.0  2800.0       5
# 1  Polyolefin Elastomer (POE)  14-July-2023  2710.0  2620.0  2800.0       5
# 2  Polyolefin Elastomer (POE)  14-July-2023  2710.0  2620.0  2800.0       9
# 3  Polyolefin Elastomer (POE)  14-July-2023  2710.0  2620.0  2800.0       9
# 4  Polyolefin Elastomer (POE)  14-July-2023  2710.0  2620.0  2800.0      18
#
#         WeekDate  Month                                ProductVarient  \
# 0  31-March-2023   None                 POE Butene Based CFR Shanghai
# ...

# %%
test_clean2['WeekDate'].value_counts()
# Out:
# 31-March-2023        36
# 14-April-2023        36
# 07-April-2023        36
# 21-April-2023        31
# 30-June-2023         27
# 01-September-2023    27
# 25-August-2023       27
# 18-August-2023       27
# 11-August-2023       27
# 04-August-2023       27
# 28-July-2023         27
# 21-July-2023         27
# 14-July-2023         27
# 07-July-2023         27
# 16-June-2023         27
# 23-June-2023         27
# 09-June-2023         27
# 02-June-2023         27
# 26-May-2023          27
# 19-May-2023          27
# 12-May-2023          27
# 05-May-2023          27
# 24-March-2023        27
# 17-March-2023        27
# 28-April-2023        27
# 08-September-2023    27
# Name: WeekDate, dtype: int64

# %%
test_clean2.head()
# Out:
#    Product                                ProductVariant  \
# 0       53  POE Butene-based Extrusion Grade FOB-Incheon
# 1       53  POE Butene-based Extrusion Grade FOB-Incheon
# 2       53  POE Butene-based Extrusion Grade FOB-Incheon
# 3       53  POE Butene-based Extrusion Grade FOB-Incheon
# 4       53  POE Butene-based Extrusion Grade FOB-Incheon
#
#                        Type_x          Date   count     Min     Max Country  \
# 0  Polyolefin Elastomer (POE)  14-July-2023  2710.0  2620.0  2800.0       5
# 1  Polyolefin Elastomer (POE)  14-July-2023  2710.0  2620.0  2800.0       5
# 2  Polyolefin Elastomer (POE)  14-July-2023  2710.0  2620.0  2800.0       9
# 3  Polyolefin Elastomer (POE)  14-July-2023  2710.0  2620.0  2800.0       9
# 4  Polyolefin Elastomer (POE)  14-July-2023  2710.0  2620.0  2800.0      18
#
#         WeekDate  Month                                ProductVarient  \
# 0  31-March-2023   None                 POE Butene Based CFR Shanghai
# ...

# %%
sub ='Price, Price change'
test_summary=test_comm[test_comm['Description'].str.contains(sub)]
test_summary.head()
# Out:
#                                             Title              Type  \
# 19629       Insights on POE Taiwan Price Movement  Chemical Pricing
# 19630          Insights on USA POE Price Movement  Chemical Pricing
# 19713      Insights on Germany POE Price Movement  Chemical Pricing
# 19716        Insights on Spain POE Price Movement  Chemical Pricing
# 19771  Insights on South Korea POE Price Movement  Chemical Pricing
#
#                                              Description  Product
# 19629  <div style="text-align:justify">\r\n\t<strong>...       53
# 19630  <div style="text-align:justify">\r\n\t<p class...       53
# 19713  <p>\r\n\t<b>Price, Price change on Monthly bas...       53
# 19716  <p>\r\n\t<b>Price, Price change on Monthly bas...       53
# 19771  <p>\r\n\t&nbsp;</p>\r\n<p class="MsoNormal">\r...       53

# %%
test_summary['Description'].iloc[0]
# Out:
# '<div style="text-align:justify">\r\n\t<strong><span style="Calibri&quot;,sans-serif;Times New Roman&quot;;\r\ncolor:#0E101A">Price, Price change monthly basis</span></strong><span spaces="true"><span style="color:#0E101A">: USD </span><span style="Times New Roman&quot;;Times New Roman&quot;;\r\ncolor:black;">3790/ton, USD -10/ton</span></span></div>\r\n<div style="text-align:justify">\r\n\t&nbsp;</div>\r\n<div style="margin:0cm;text-align:justify">\r\n\t<strong><span style="font-size:11.0pt;Calibri&quot;,sans-serif;color:#0E101A">Summary:</span></strong><span spaces="true"><span style="font-size:11.0pt;Calibri&quot;,sans-serif;color:#0E101A">&nbsp;Prices fell mainly as feedstocks (Polypropylene) fluctuated and consumption levels remained stagnant to low.</span></span></div>\r\n<div style="margin:0cm;text-align:justify">\r\n\t&nbsp;</div>\r\n<div style="margin:0cm;text-align:justify">\r\n\t<strong><span spaces="true"><span style="font-size:11.0pt;Calibri&quot;,sans-serif;color:#0E101
# ...

# %%
test.loc[test['Supply']==' Low to Moderate ']
# Out:
# Empty DataFrame
# Columns: [Product, ProductVariant, Type_x, Date, count, Min, Max, Country, WeekDate, Month, ProductVarient, Type_y, MarketSituation, Demand, Supply, PlantShutdown]
# Index: []

# %%
####  GPT
#########################  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
keys='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'

# %%
pip install openai
# Out:
# ...
#   Obtaining dependency information for openai from https://files.pythonhosted.org/packages/ae/59/911d6e5f1d7514d79c527067643376cddcf4cb8d1728e599b3b03ab51c69/openai-0.28.0-py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/76.5 kB ? eta -:--:--
#    ----- ---------------------------------- 10.2/76.5 kB ? eta -:--:--
#    ---------------- ----------------------- 30.7/76.5 kB 325.1 kB/s eta 0:00:01
#    -------------------------------- ------- 61.4/76.5 kB 465.5 kB/s eta 0:00:01
#    ---------------------------------------- 76.5/76.5 kB 422.3 kB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# DEPRECATION: Loading egg at c:\users\web.dev-1\appdata\local\anaconda3\lib\site-packages\huggingface_hub-0.17.0rc0-py3.8.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..

# %%
import openai

import os

import pandas as pd

import time

# %%
openai.api_key = keys

def get_completion_with_retry(prompt, retries=3, delay=5):
    for i in range(retries):
        try:
            # Initialize the GPT-3 API client
            openai.api_key = "your-openai-api-key-here"
            
            # Make a completion request
            response = openai.Completion.create(
              engine="text-davinci-002",
              prompt=prompt,
              max_tokens=60
            )
            
            return response.choices[0].text.strip()

        except openai.Error as e:
            if e.__class__.__name__ == 'RateLimitError':
                print(f"Rate limit exceeded. Retrying in {delay} seconds...")
                time.sleep(delay)
                delay *= 2  # Exponential backoff
            else:
                print(f"An error occurred: {e}")
                break

# %%
prompt = "Hi"
response = get_completion(prompt)
print(response)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[36], line 2
#       1 prompt = "Hi"
# ----> 2 response = get_completion(prompt)
#       3 print(response)
#
# Cell In[28], line 4, in get_completion(prompt, model)
#       2 def get_completion(prompt, model="gpt-3.5-turbo"):
#       3     messages = [{"role": "user", "content": prompt}]
# ----> 4     response = openai.ChatCompletion.create(
#       5     model=model,
#       6     messages=messages,
#       7     temperature=0,
#       8     )
#       9     return response.choices[0].message["content"]
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\openai\api_resources\chat_completion.py:25, in ChatCompletion.create(cls, *args, **kwargs)
#      23 while True:
#      24     try:
# ---> 25         return super().create(*args, **kwargs)
#      26     except TryAgain as e:
# ...

# %%
com.head()
# Out:
#     id                                              Title              Type  \
# 0  714    Insights on Polyolefin Elastomer Price Movement  Chemical Pricing
# 1  715  Insights on Thermo Plastic Elastomer (TPE) Pri...  Chemical Pricing
# 2  719  Insights on Thermo Plastic Elastomer (TPE) Pri...  Chemical Pricing
# 3  721              Insights on Helium Gas Price Movement  Chemical Pricing
# 4  724              Insights on Helium Gas Price Movement  Chemical Pricing
#
#                                          Description  Meta MetaDescription  \
# 0  <div>\r\n\t<div>\r\n\t\t&nbsp;</div>\r\n\t<div...  None            None
# 1  <div>\r\n\tDue to less demand, northeast Asian...  None            None
# 2  <div>\r\n\tPrices of the raw material went dow...  None            None
# 3  <div>\r\n\tThe cost of Helium Gas has risen by...  None            None
# 4  <div>\r\n\tTight supplies made the price incre...  None            None
#
# ...

# %%
com['Description'].iloc[0]
# Out:
# '<div>\r\n\t<div>\r\n\t\t&nbsp;</div>\r\n\t<div>\r\n\t\t<div>\r\n\t\t\tIndia Polyolefin Elastomer market was steady in terms of price this month, and demand was slightly softer in some applications such as film packaging. The monthly prices Ex-Depot Delhi NCR dropped down to INR 124000 per MT for C2 &amp; C8 POE.</div>\r\n\t</div>\r\n</div>\r\n'
